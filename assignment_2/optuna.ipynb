# %%
import pandas as pd

from sklearn.metrics import make_scorer, matthews_corrcoef, balanced_accuracy_score, \
    f1_score, fbeta_score, recall_score, precision_score, average_precision_score, accuracy_score

# %%
df = pd.read_csv('Hepatitis_C.csv')
df
# Out:
#      Age  Sex   ALB    ALP    ALT    AST   BIL   CHE  CHOL  CREA    GGT  PROT  \
# 0     32    0  43.2   52.0   30.6   22.6  18.9  7.33  4.74  80.0   33.8  75.7
# 1     45    0  41.7   73.2   43.6   29.4   6.4  8.89  5.31  71.0   67.4  70.3
# 2     55    0  41.5   59.5   15.4   16.2   6.8  6.35  5.22  80.0   12.4  69.9
# 3     53    0  37.8   98.1   30.5   21.1   4.0  5.02  4.42  94.0   23.2  65.2
# 4     56    1  39.7   66.0   14.2   20.8   3.5  7.48  5.88  66.0    7.2  67.2
# ..   ...  ...   ...    ...    ...    ...   ...   ...   ...   ...    ...   ...
# 199   62    1  32.0  416.6    5.9  110.3  50.0  5.57  6.30  55.7  650.9  68.5
# 200   64    1  24.0  102.8    2.9   44.4  20.0  1.54  3.02  63.0   35.9  71.3
# 201   64    1  29.0   87.3    3.5   99.0  48.0  1.66  3.63  66.7   64.2  82.0
# 202   46    1  33.0   62.7   39.0   62.0  20.0  3.56  4.20  52.0   50.0  71.0
# 203   59    1  36.0   62.7  100.0   80.0  12.0  9.07  5.30  67.0   34.0  68.0
#
#      label
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 199      1
# 200      1
# 201      1
# 202      1
# 203      1
#
# [204 rows x 13 columns]

# %% [markdown]
# ## Train/Test split

# %%
from sklearn.model_selection import train_test_split

# -- Separate features and label
# (a) drop target column
X = df.drop(columns=['label'])
# (b) make an array with the target column
y = df['label'].copy()

# -- Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, \
                                                    stratify=y, random_state=42)

print(X_train.shape, X_test.shape)
# Out:
# (163, 12) (41, 12)

# %% [markdown]
# ## Simple Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

model = SVC()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
score = matthews_corrcoef(y_pred=y_pred, y_true=y_test)
print(score)

results = pd.DataFrame({'true': y_test, 'pred': y_pred})
display(results.head())
# Out:
# 0.8409178658720822
#      true  pred
# 37      0     0
# 191     1     1
# 20      0     0
# 149     1     0
# 21      0     0

# %% [markdown]
# # Optuna

# %% [markdown]
# Optuna is an open-source hyperparameter optimization framework for Python. It provides a simple and efficient API for defining and optimizing machine learning models. Optuna automates the process of hyperparameter tuning by intelligently exploring the hyperparameter space and finding the optimal set of hyperparameters that minimize a user-defined objective function.
#
# Optuna uses state-of-the-art algorithms for hyperparameter search, such as Tree-structured Parzen Estimator (TPE), Bayesian optimization, and Optuna's original algorithm called "Pruner". It also supports various machine learning frameworks such as PyTorch, TensorFlow, Keras, and Scikit-learn.
#
# With Optuna, you can define a search space of hyperparameters, specify the objective function that you want to minimize, and run the optimization process. The framework then uses its algorithms to search for the best hyperparameters within the specified search space, and returns the optimal set of hyperparameters that yield the best performance of the objective function.

# %%
import optuna
from optuna.samplers import TPESampler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score

# %%
def objective(trial, model):
    # -- Tune estimator algorithm
    # Wrap the objective inside a lambda and call objective inside it
    params = {
            'C':trial.suggest_loguniform('C', 1e-3, 1e3),
            'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
        }

    clf = model.set_params(**params)
    # -- Cross-validate the features reduced by dimensionality reduction methods
    kfold = StratifiedKFold(n_splits=10)
    score = cross_val_score(clf, X_train, y_train, scoring='matthews_corrcoef', cv=kfold)
    score = score.mean()
    return score


model = SVC()

_objective = lambda trial: objective(trial, model)

sampler = TPESampler(seed=42) # create a seed for the sampler for reproducibility
study = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(_objective, n_trials=100)
# Out:
# [I 2023-04-06 17:10:50,334] A new study created in memory with name: no-name-f427c9c7-bba0-4538-acf2-ccadada80749
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:50,394] Trial 0 finished with value: 0.0 and parameters: {'C': 0.1767016940294795, 'gamma': 506.1576888752306}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:50,458] Trial 1 finished with value: 0.0 and parameters: {'C': 24.658329458549105, 'gamma': 3.907967156822881}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:50,524] Trial 2 finished with value: 0.0 and parameters: {'C': 0.008632008168602538, 'gamma': 0.008629132190071854}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:50,588] Trial 3 finished with value: 0.0 and parameters: {'C': 0.002231010801867922, 'gamma': 157.41890047456639}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:50,666] Trial 4 finished with value: 0.0 and parameters: {'C': 4.0428727350273315, 'gamma': 17.71884735480682}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:50,726] Trial 5 finished with value: 0.0 and parameters: {'C': 0.0013289448722869186, 'gamma': 659.871107205407}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:50,869] Trial 6 finished with value: 0.0 and parameters: {'C': 98.77700294007911, 'gamma': 0.018794668241638456}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:50,941] Trial 7 finished with value: 0.0 and parameters: {'C': 0.012329623163659839, 'gamma': 0.012601639723276799}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,005] Trial 8 finished with value: 0.0 and parameters: {'C': 0.06690421166498801, 'gamma': 1.40779231399724}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,070] Trial 9 finished with value: 0.0 and parameters: {'C': 0.3905441275210791, 'gamma': 0.055895242052179224}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,147] Trial 10 finished with value: 0.0 and parameters: {'C': 468.6183228417102, 'gamma': 48.2110058077512}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,213] Trial 11 finished with value: 0.0 and parameters: {'C': 7.096419550009027, 'gamma': 4.12400843781731}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,273] Trial 12 finished with value: 0.0 and parameters: {'C': 0.43041970532508544, 'gamma': 0.2163590635361023}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,340] Trial 13 finished with value: 0.0 and parameters: {'C': 20.11248631900398, 'gamma': 768.754145148502}. Best is trial 0 with value: 0.0.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,406] Trial 14 finished with value: 0.8544451325330676 and parameters: {'C': 1.9290764819348207, 'gamma': 0.0011996661220636685}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,473] Trial 15 finished with value: 0.8544451325330676 and parameters: {'C': 1.361078898826083, 'gamma': 0.0012681184886266892}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,536] Trial 16 finished with value: 0.842722444648914 and parameters: {'C': 1.5511552367423218, 'gamma': 0.0015832235628075492}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,609] Trial 17 finished with value: 0.8267653261863084 and parameters: {'C': 2.304346574157571, 'gamma': 0.001318673537076355}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,668] Trial 18 finished with value: 0.8544451325330676 and parameters: {'C': 1.1737804231162743, 'gamma': 0.0011140982067976005}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,746] Trial 19 finished with value: 0.0 and parameters: {'C': 0.08918500782759606, 'gamma': 0.1759385955452769}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,826] Trial 20 finished with value: 0.8168267884158975 and parameters: {'C': 8.701058186728083, 'gamma': 0.002847548483939779}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,900] Trial 21 finished with value: 0.828001647014587 and parameters: {'C': 0.761004625148734, 'gamma': 0.0013200153805701309}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:51,981] Trial 22 finished with value: 0.23068695971780562 and parameters: {'C': 1.7287040155934588, 'gamma': 0.00446993724074825}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:52,071] Trial 23 finished with value: 0.0 and parameters: {'C': 0.7722020634513983, 'gamma': 0.005712242329649445}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:52,160] Trial 24 finished with value: 0.8445065947626569 and parameters: {'C': 3.4357824899669884, 'gamma': 0.0010182050492314597}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:52,273] Trial 25 finished with value: 0.0 and parameters: {'C': 0.3881324717559617, 'gamma': 0.020397388849447497}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:52
. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:54,591] Trial 55 finished with value: 0.0 and parameters: {'C': 0.566626746186949, 'gamma': 0.006186542904687673}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:54,668] Trial 56 finished with value: 0.842722444648914 and parameters: {'C': 0.9603890134728147, 'gamma': 0.001785389514124687}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:54,731] Trial 57 finished with value: 0.8168267884158975 and parameters: {'C': 10.926285120520193, 'gamma': 0.003482659289991793}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:54,810] Trial 58 finished with value: 0.8445065947626569 and parameters: {'C': 21.529827573575137, 'gamma': 0.001024709345398893}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# ...
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:56,563] Trial 80 finished with value: 0.0 and parameters: {'C': 0.4659729602183526, 'gamma': 0.0058316843002333635}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:56,653] Trial 81 finished with value: 0.8445065947626569 and parameters: {'C': 13.614643475798172, 'gamma': 0.0010058387942850715}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:56,737] Trial 82 finished with value: 0.8168267884158975 and parameters: {'C': 15.851542512453753, 'gamma': 0.002235712053523363}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:56,819] Trial 83 finished with value: 0.842722444648914 and parameters: {'C': 3.1487509482220135, 'gamma': 0.0013876689813781835}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:56,905] Trial 84 finished with value: 0.842722444648914 and parameters: {'C': 24.321991847302456, 'gamma': 0.001977679287972038}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:57,010] Trial 85 finished with value: 0.8168267884158975 and parameters: {'C': 2.2998363617657334, 'gamma': 0.003079475270833019}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:57,100] Trial 86 finished with value: 0.842722444648914 and parameters: {'C': 7.580904131127998, 'gamma': 0.00137926373847672}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:57,170] Trial 87 finished with value: 0.8168267884158975 and parameters: {'C': 5.842159250222501, 'gamma': 0.003556558836230811}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:57,232] Trial 88 finished with value: 0.8544451325330676 and parameters: {'C': 0.7818663837791822, 'gamma': 0.0010021896780255874}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:57,297] Trial 89 finished with value: 0.8409628190367382 and parameters: {'C': 0.6643475371167634, 'gamma': 0.0018010932651789493}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:57,363] Trial 90 finished with value: 0.0 and parameters: {'C': 0.30896047804094046, 'gamma': 0.008426372181096198}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:57,444] Trial 91 finished with value: 0.8544451325330676 and parameters: {'C': 0.9082292156926386, 'gamma': 0.0010126196102057364}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:57,513] Trial 92 finished with value: 0.842722444648914 and parameters: {'C': 0.8835491272314869, 'gamma': 0.0013107297974275722}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:57,580] Trial 93 finished with value: 0.8327839068785032 and parameters: {'C': 1.4316266637639945, 'gamma': 0.002101431899826123}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:57,671] Trial 94 finished with value: 0.0 and parameters: {'C': 0.7650111217744475, 'gamma': 0.004588404528040595}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:57,764] Trial 95 finished with value: 0.8168267884158975 and parameters: {'C': 1.8143596610310293, 'gamma': 0.0026003768312651268}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:57,850] Trial 96 finished with value: 0.838488014070462 and parameters: {'C': 2.7231099399230696, 'gamma': 0.001301696142000491}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:57,919] Trial 97 finished with value: 0.842722444648914 and parameters: {'C': 1.1363338408036974, 'gamma': 0.0019916775930892573}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:58,005] Trial 98 finished with value: 0.8544451325330676 and parameters: {'C': 0.8138171372964593, 'gamma': 0.0010266552599051799}. Best is trial 14 with value: 0.8544451325330676.
# /tmp/ipykernel_25386/4179246629.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C':trial.suggest_loguniform('C', 1e-3, 1e3),
# /tmp/ipykernel_25386/4179246629.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'gamma':trial.suggest_loguniform('gamma', 1e-3, 1e3)
# [I 2023-04-06 17:10:58,069] Trial 99 finished with value: 0.8267653261863084 and parameters: {'C': 0.7469631464578268, 'gamma': 0.002802955312369357}. Best is trial 14 with value: 0.8544451325330676.

# %%
print(study.best_params)
print(study.best_value)

model = SVC().set_params(**study.best_params)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

f1_score(y_pred=y_pred, y_true=y_test)
# Out:
# {'C': 1.9290764819348207, 'gamma': 0.0011996661220636685}
# 0.8544451325330676
# 0.9285714285714286
